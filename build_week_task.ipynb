# %%
import pandas as pd
import seaborn as sb 
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv('dataset_5secondWindow.csv')
data1.head(10)
# Out:
#    Unnamed: 0     id   time  activityrecognition#0  activityrecognition#1  \
# 0           0  16170   78.0                    NaN                  100.0
# 1           1  15871  145.0                    NaN                  100.0
# 2           2  16811  150.0                    NaN                  100.0
# 3           3  15831  105.0                    NaN                   77.0
# 4           4    876   77.0                    NaN                  100.0
# 5           5  13480  559.0                    NaN                  100.0
# 6           6  18786   41.0                    NaN                  100.0
# 7           7  15268   20.0                    NaN                  100.0
# 8           8    343   35.0                    NaN                  100.0
# 9           9   4650   27.0                    NaN                   69.0
#
#    android.sensor.accelerometer#mean  android.sensor.accelerometer#min  \
# 0                           9.811476                          9.758895
# ...

# %%
data1.shape
# sb.heatmap(data1)
# sb.heatmap(data1.isna().transpose(), cmap="YlGnBu", cbar_kws={'label': 'Missing Data'})
# fig = sb.heatmap(data1.isna(), cmap="YlGnBu", cbar_kws={'label': 'Missing Data'})
# Out:
# (5893, 71)

# %%
# sb.heatmap(data1)
# sb.heatmap(data1.isna().transpose(), cmap="YlGnBu", cbar_kws={'label': 'Missing Data'})
fig = sb.heatmap(data1.isna(), cmap="YlGnBu", cbar_kws={'label': 'Missing Data'})

# %%
plt.figure(figsize=(25,18))
sb.displot(data=data1.isna().melt(value_name="missing"),  y="variable",  hue="missing",  multiple="fill",   aspect=1.25)

# %%
print(data1.columns.unique())
# Out:
# Index(['Unnamed: 0', 'id', 'time', 'activityrecognition#0',
#        'activityrecognition#1', 'android.sensor.accelerometer#mean',
#        'android.sensor.accelerometer#min', 'android.sensor.accelerometer#max',
#        'android.sensor.accelerometer#std',
#        'android.sensor.game_rotation_vector#mean',
#        'android.sensor.game_rotation_vector#min',
#        'android.sensor.game_rotation_vector#max',
#        'android.sensor.game_rotation_vector#std',
#        'android.sensor.gravity#mean', 'android.sensor.gravity#min',
#        'android.sensor.gravity#max', 'android.sensor.gravity#std',
#        'android.sensor.gyroscope#mean', 'android.sensor.gyroscope#min',
#        'android.sensor.gyroscope#max', 'android.sensor.gyroscope#std',
#        'android.sensor.gyroscope_uncalibrated#mean',
#        'android.sensor.gyroscope_uncalibrated#min',
#        'android.sensor.gyroscope_uncalibrated#max',
#        'android.sensor.gyroscope_uncalibrated#std',
# ...

# %%
data2 = pd.read_csv('dataset_halfSecondWindow.csv')
data2.head(6)
# Out:
#    Unnamed: 0      id  time  activityrecognition#0  activityrecognition#1  \
# 0           0  156661   3.0                    NaN                   62.0
# 1           1  156662   4.0                    NaN                   62.0
# 2           2  156663   5.0                    NaN                   62.0
# 3           3  156664   6.0                    NaN                   62.0
# 4           4  156665   7.0                    NaN                   62.0
# 5           5  156666   8.0                    NaN                   62.0
#
#    android.sensor.accelerometer#mean  android.sensor.accelerometer#min  \
# 0                          10.053802                          4.328630
# 1                          10.687402                          6.373194
# 2                          11.816800                          4.817410
# 3                           9.401312                          6.124588
# 4                          10.389851                          5.313790
# ...

# %%
# sb.heatmap(data1)
# sb.heatmap(data1.isna().transpose(), cmap="YlGnBu", cbar_kws={'label': 'Missing Data'})
fig = sb.heatmap(data2.isna(), cmap="YlGnBu", cbar_kws={'label': 'Missing Data'})

# %%
col_names = [ 
              'Unnamed: 0',                                    'id',                                                   'time', 
	       'activityrecognition#0',                         'activityrecognition#1',                                'android.sensor.accelerometer#mean',
              'android.sensor.game_rotation_vector#mean',      'android.sensor.gravity#mean',                          'android.sensor.gyroscope#mean', 
              'android.sensor.gyroscope_uncalibrated#mean',    'android.sensor.light#mean',                            'android.sensor.linear_acceleration#mean',
              'android.sensor.magnetic_field#mean',            'android.sensor.magnetic_field_uncalibrated#mean',      'android.sensor.orientation#mean', 
              'android.sensor.pressure#mean',                  'android.sensor.proximity#mean',                        'android.sensor.rotation_vector#mean',
              'android.sensor.step_counter#mean',              'sound#mean',                                           'speed#mean',
              'target',                                        'user'
            ]

# %%
features_mean_5_sec    = data1[col_names]
features_mean_half_sec = data2[col_names]

# %%
fig = sb.heatmap(features_mean_5_sec.isna(), cmap="YlGnBu", cbar_kws={'label': 'Missing Data'})

# %%
fig = sb.heatmap(features_mean_half_sec.isna(), cmap="YlGnBu", cbar_kws={'label': 'Missing Data'})

# %%
new_columns_names = [ 
              'activityrecognition#1',                                'android.sensor.accelerometer#mean',
              'android.sensor.game_rotation_vector#mean',      'android.sensor.gravity#mean',                          'android.sensor.gyroscope#mean', 
              'android.sensor.gyroscope_uncalibrated#mean',    'android.sensor.linear_acceleration#mean',
              'android.sensor.magnetic_field#mean',            'android.sensor.magnetic_field_uncalibrated#mean',      'android.sensor.orientation#mean', 
              'android.sensor.rotation_vector#mean',  
              'sound#mean',                                           'speed#mean',
              'target',                                        
            ]

# %%
df3 = data2[new_columns_names]
df3.head(5)
# Out:
#    activityrecognition#1  android.sensor.accelerometer#mean  \
# 0                   62.0                          10.053802
# 1                   62.0                          10.687402
# 2                   62.0                          11.816800
# 3                   62.0                           9.401312
# 4                   62.0                          10.389851
#
#    android.sensor.game_rotation_vector#mean  android.sensor.gravity#mean  \
# 0                                  0.629076                     9.806645
# 1                                  0.577839                     9.806640
# 2                                  0.651511                     9.806636
# 3                                  0.713226                     9.806635
# 4                                  0.707375                     9.806633
#
#    android.sensor.gyroscope#mean  android.sensor.gyroscope_uncalibrated#mean  \
# 0                       3.268103                                    3.278420
# ...

# %%
df3.shape
# Out:
# (62585, 14)

# %%
df4 = df3.dropna()

# %%
df4.shape
# Out:
# (25199, 14)

# %%
fig = sb.heatmap(df4.isna(), cmap="YlGnBu", cbar_kws={'label': 'Missing Data'})

# %%
df4.columns
# Out:
# Index(['activityrecognition#1', 'android.sensor.accelerometer#mean',
#        'android.sensor.game_rotation_vector#mean',
#        'android.sensor.gravity#mean', 'android.sensor.gyroscope#mean',
#        'android.sensor.gyroscope_uncalibrated#mean',
#        'android.sensor.linear_acceleration#mean',
#        'android.sensor.magnetic_field#mean',
#        'android.sensor.magnetic_field_uncalibrated#mean',
#        'android.sensor.orientation#mean',
#        'android.sensor.rotation_vector#mean', 'sound#mean', 'speed#mean',
#        'target'],
#       dtype='object')

# %%
X_columns = ['android.sensor.accelerometer#mean',
      'android.sensor.gyroscope#mean',
       'sound#mean']
X = df4[X_columns]

# %%
X_columns = ['activityrecognition#1', 'android.sensor.accelerometer#mean',
       'android.sensor.game_rotation_vector#mean',
       'android.sensor.gravity#mean', 'android.sensor.gyroscope#mean',
       'android.sensor.gyroscope_uncalibrated#mean',
       'android.sensor.linear_acceleration#mean',
       'android.sensor.magnetic_field#mean',
       'android.sensor.magnetic_field_uncalibrated#mean',
       'android.sensor.orientation#mean',
       'android.sensor.rotation_vector#mean', 'sound#mean', 'speed#mean']
X = df4[X_columns]

# %%
X
# Out:
#        android.sensor.accelerometer#mean  android.sensor.gyroscope#mean  \
# 2168                            7.792795                       1.557897
# 2169                            9.449157                       1.557897
# 2170                            9.759530                       1.557897
# 2171                            9.319336                       0.612964
# 2172                            9.430259                       0.612964
# ...                                  ...                            ...
# 62580                          10.105329                       0.025664
# 62581                           9.544118                       1.338389
# 62582                          14.258467                       0.984748
# 62583                          10.726491                       1.779868
# 62584                          15.892297                       1.376634
#
#        sound#mean
# 2168    77.815125
# 2169    77.815125
# 2170    77.815125
# 2171    77.815125
# ...

# %%
y = df4['target']
y
# Out:
# 2168         Bus
# 2169         Bus
# 2170         Bus
# 2171         Bus
# 2172         Bus
#           ...
# 62580    Walking
# 62581    Walking
# 62582    Walking
# 62583    Walking
# 62584    Walking
# Name: target, Length: 25199, dtype: object

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.tree        import DecisionTreeClassifier
from sklearn.ensemble    import RandomForestClassifier
from sklearn.svm         import SVC

# %%
model_decision_tree = DecisionTreeClassifier()
model_random_forest = RandomForestClassifier()
model_SVC           = SVC()

# %%
model_decision_tree.fit(X_train, y_train)
model_random_forest.fit(X_train, y_train)
model_SVC.fit(X_train, y_train)

# %%
accuracy_decision_tree = model_decision_tree.score(X_test, y_test)
accuracy_random_forest = model_random_forest.score(X_test, y_test)
accuracy_SVC           = model_SVC.score(X_test, y_test)

# %%
print('Decision Tree : ', round(accuracy_decision_tree *100, 2))
print('Random Forest : ', round(accuracy_random_forest*100, 2))
print('SVC           : ', round(accuracy_SVC*100, 2))

# %%
accuracy_train_decision_tree = model_decision_tree.score(X_train, y_train)
accuracy_train_random_forest = model_random_forest.score(X_train, y_train)
accuracy_train_SVC           = model_SVC.score(X_train, y_train)

# %%
print('Decision Tree : ', round(accuracy_train_decision_tree *100, 2))
print('Random Forest : ', round(accuracy_train_random_forest*100, 2))
print('SVC           : ', round(accuracy_train_SVC*100, 2))
